# %% [markdown]
# # Inserting a "CSV" file data into MongoDB database with pymongo

# %%
#import pymongo module to connect and interact with MongoDB 
#replaced password with *******
import pymongo
link=pymongo.MongoClient("mongodb://sakthivel:*******@ac-ppyctse-shard-00-00.tmwrsy2.mongodb.net:27017,ac-ppyctse-shard-00-01.tmwrsy2.mongodb.net:27017,ac-ppyctse-shard-00-02.tmwrsy2.mongodb.net:27017/?ssl=true&replicaSet=atlas-4x48lc-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
#import pandas module to read csv file into dataframe format
from pandas import *
df=read_csv("C:/Users/shakt/Downloads/Restaurant.csv")
df
# Out:
#                            _id  \
# 0     63ce66607db9750b15fcc568
# 1     63ce66607db9750b15fcc566
# 2     63ce66607db9750b15fcc56c
# 3     63ce66607db9750b15fcc56f
# 4     63ce66607db9750b15fcc56e
# ...                        ...
# 3767  63ce66607db9750b15fcd3f5
# 3768  63ce66607db9750b15fcd3f7
# 3769  63ce66607db9750b15fcd400
# 3770  63ce66607db9750b15fcd408
# 3771  63ce66607db9750b15fcd40d
#
#                                                 address        borough  \
# 0     {'building': '351', 'coord': [-73.985135599999...      Manhattan
# 1     {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 2     {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 3     {'building': '1839', 'coord': [-73.9482609, 40...       Brooklyn
# 4     {'building': '6409', 'coord': [-74.00528899999...       Brooklyn
# ...                                                 ...            ...
# 3767  {'building': '495', 'coord': [-73.9781038, 40....      Manhattan
# ...

# %%
#converting datafram into dictionary format
df_dict=df.to_dict('records')

# %%
#Creating a new database
DB=link['Test']

# %%
#creating a new collection inside the database
DB_coll=DB['Rest_collection']

# %%
#inserting the data(dictionary format) into the Mongodb database collection
DB_coll.insert_many(df_dict)
